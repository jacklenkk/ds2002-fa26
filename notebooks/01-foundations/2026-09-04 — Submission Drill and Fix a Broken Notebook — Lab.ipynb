# %% [markdown]
# # DS2002 · Submission Drill and Fix a Broken Notebook
#
# **Lab — 2026-09-04 · Fall 2026**
#
# ---

# %% [markdown]
# ## Lab 02 — Submission Drill and Fix a Broken Notebook
#
# You have inherited a notebook that does not run. This is the most common way you will meet other people's code, so it is worth practicing deliberately.
#
# Seven cells below are broken. Five throw an error, and two return a wrong answer without complaining at all — those are the dangerous ones. Fix all seven, prove your fixes with assertions, then push through the full submit loop.
#
# **Submit in Canvas:** repository link and notebook link.

# %% [markdown]
# ### How to read an error before you fix it
#
# Python's traceback is read **bottom up**. The last line names the exception and the problem; the line above it points at your code.
#
# ```
# Traceback (most recent call last):
#   File "<stdin>", line 2, in <module>
#     print(greeting)
# NameError: name 'greeting' is not defined
# ```
#
# Four exceptions cover most of what you will hit this semester:
#
# | Exception | Usually means |
# |---|---|
# | `NameError` | The variable was never created, or the cell that created it never ran |
# | `TypeError` | You mixed types — text where a number belongs is the classic |
# | `KeyError` | That column or dictionary key does not exist. Check spelling and case |
# | `FileNotFoundError` | The path is wrong for *this* environment |
#
# For each fix below, write one sentence in the markdown cell saying what was actually wrong. "It works now" is not a diagnosis.

# %% [markdown]
# ### Bug 1 — a name that does not exist

# %%
greeting = "Hello, how are you doing?"
print(greeting)
# Out:
# Hello, how are you doing?

# %% [markdown]
# **What was wrong:** The variable "greeting" was never defined so trying to print it threw a NameError. I fixed this by setting "greeting" equal to a valid string, which enabled the print statement to properly display the output.

# %% [markdown]
# ### Bug 2 — text where a number belongs
#
# This should print `30`. Note that `'10' + 20` and `'10' + '20'` fail in different ways — make sure you know which one you are looking at.

# %%
total = 10 + 20
print(total)
# Out:
# 30

# %% [markdown]
# **What was wrong:** The "total" variable was attempting to add a string type to an integer type, which threw a TypeError. I fixed this by changing '10' to just 10, making it so two integer types were added and 30 was produced.

# %% [markdown]
# ### Bug 3 — off the end of a list

# %%
items = ['burger', 'poncho', 'hat']
print(items[len(items) - 1])
# Out:
# hat

# %% [markdown]
# **What was wrong:** The list was attempting to print an item at an index that was out-of-bounds, which threw an IndexError. I fixed this by having the last item always be indexed at the length of the list - 1, so that the 0 index is properly accounted for and the correct item is printed.

# %% [markdown]
# ### Bug 4 — no error, wrong answer
#
# This is supposed to be the average. It prints a number, and the number is wrong.

# %%
nums = [2, 4, 6, 8]
average = sum(nums) / len(nums)
print('average:', average)
# Out:
# average: 5.0

# %% [markdown]
# **What was wrong:** The average was being calculated by dividing the sum of all numbers by 2, which produces an incorrect result. I fixed this by dividing the sum of all numbers by the length of the list of the numbers, accurately producing the average.

# %% [markdown]
# ### Bug 5 — a table that cannot exist

# %%
import pandas as pd

df = pd.DataFrame({'item': ['a', 'b'], 'price': [1, 2]})
print(df)
# Out:
#   item  price
# 0    a      1
# 1    b      2

# %% [markdown]
# **What was wrong:** The 'item' column had a length of 2 and the 'price' column had a length of 3 which threw a ValueError. I fixed this by removing the extra "3" in 'price', making both columns equal length and correctly creating the table.

# %% [markdown]
# ### Bug 6 — the answer changes when you re-run it
#
# Run the next cell three times and watch the total move. Then fix it using what you built Wednesday: leave the source data alone and derive a new column from it. Your fix must give the same total on every run.

# %%
sales = pd.DataFrame({
    'game': ['NC State', 'Louisville'],
    'units': [1450, 1610],
})

# %%
work = sales.copy()
work['fee'] = sales['units'] * 1.05
print('total units:', round(work['fee'].sum(), 2))
# Out:
# total units: 3213.0

# %%
for _ in range(3):
    work = sales.copy()
    work['fee'] = sales['units'] * 1.05 
    print('total units:', round(work['fee'].sum(), 2))
# Out:
# total units: 3213.0
# total units: 3213.0
# total units: 3213.0

# %% [markdown]
# **What was wrong:** The sales['units'] column was compounding values each time the cell ran instead of starting from the original value, resulting in a new sales['units'] column total on each run. I fixed this by creating a new variable "work" to copy the sales table on each run, resulting in the same original sales['units'] value being used each time the cell ran, producing the same total every time.

# %% [markdown]
# ### Bug 7 — a path from someone else's laptop
#
# This notebook was written on a machine you do not have. Fix it with the pattern from Wednesday's studio: look for the file, and fall back to the inline sample so the notebook still runs for whoever opens it next.

# %%
import os
from io import StringIO

SAMPLE = '''game,units\nNC State,1450\nLouisville,1610\n'''

def load_csv(filename, sample=SAMPLE):
    if os.path.exists(filename):
        print("I used the real file.")
        return pd.read_csv(filename)
    else:
        print("I fell back to the sample string.") 
        return pd.read_csv(StringIO(sample))
orders = load_csv('gameday_orders.csv')
orders
# Out:
# I fell back to the sample string.
#          game  units
# 0    NC State   1450
# 1  Louisville   1610

# %% [markdown]
# **What was wrong:** A file path from another person's computer was used, resulting in my computer not being able to find the file and throwing a FileNotFoundError. I fixed this by first checking if the file exists on my computer, and if it doesn't I fall back to the sample.

# %% [markdown]
# ### Part 8 — prove the fixes
#
# Assertions are how you state what must be true. If one fails, the notebook stops and tells you which claim broke — much better than scrolling for a wrong number.
#
# **TODO:** uncomment each line and make them all pass.

# %%
assert isinstance(greeting, str) and greeting != ''
assert total == 30
assert items[-1] == 'hat'
assert average == 5
assert len(df) == 2
assert len(orders) >= 2
print('All checks passed.')
# Out:
# All checks passed.

# %% [markdown]
# ### Part 9 — the submit drill
#
# This is the part that is actually being graded on process. Do it in order.
#
# 1. **Restart the kernel and Run All.** Zero errors, top to bottom.
# 2. Download the notebook and put it in your repo under `notebooks/01-foundations/`, named `2026-09-04 — Submission Drill and Fix a Broken Notebook — Lab.ipynb`.
# 3. Commit with a message that says what you did, then push.
# 4. Confirm on github.com that the file is there and opens.
# 5. Fill in the cell below and submit both links in Canvas.
#
# **TODO:** fill in the four values and make the check pass.

# %%
import re

repo_url = 'https://github.com/jacklenkk/ds2002-fa26'
commit_sha = 'dc34edb'
notebook_link = 'https://colab.research.google.com/github/jacklenkk/ds2002-fa26/blob/main/notebooks/01-foundations/2026-09-04%20%E2%80%94%20Submission%20Drill%20and%20Fix%20a%20Broken%20Notebook%20%E2%80%94%20Lab.ipynb#scrollTo=jukNyADGLK91'
ran_restart_and_run_all = True

checks = {
    'repo URL is a github.com URL':
        repo_url.startswith('https://github.com/')
        and repo_url.count('/') >= 4,
    'commit hash looks like a hash':
        bool(re.fullmatch(r'[0-9a-f]{7,40}', commit_sha.strip())),
    'notebook link filled in':
        notebook_link.startswith('http'),
    'restarted and ran all':
        ran_restart_and_run_all is True,
}

for label, passed in checks.items():
    print('PASS' if passed else 'FAIL', '-', label)

print()
print('Ready to submit:', all(checks.values()))
# Out:
# PASS - repo URL is a github.com URL
# PASS - commit hash looks like a hash
# PASS - notebook link filled in
# PASS - restarted and ran all
#
# Ready to submit: True

# %% [markdown]
# ### Write-up
#
# Bugs 4 and 6 did not raise an error. In a few sentences: how would you catch that class of bug in a project where you do not already know the right answer? Name something concrete you could add to a notebook.

# %% [markdown]
# I would catch that class of bug in a project where I didn't already know the right answer by completing those calculations myself outside of the code and making sure my answer and the code's answer match. Something concrete that could be added to a notebook are tests on the code that take an input and assert an expected output. Any bugs in the code would be revealed if these tests fail, allowing me the opportunity to fix the code and then run all the tests again until they all pass on given inputs.

# %% [markdown]
# ### Stretch
#
# Write a `check_orders(df)` function that raises a clear error if the frame is missing either expected column, has zero rows, or contains a negative value in `units`. Then call it on `orders`. This is the shape of validation you will want in both projects.

# %%
def check_orders(df):
    if 'game' not in df.columns or 'units' not in df.columns:
        raise ValueError("Missing an expected game or units column") 
    if len(df) == 0:
        raise ValueError("Table has zero rows") 
    for i in df['units']:
        if i < 0:
            raise ValueError("Units contains a negative value")
check_orders(orders)

# %% [markdown]
# Explanation: I created a check_orders(df) function that first checks if any expected columns are missing, then checks if there are zero rows, and then checks if any value in units is negative. If any of these checks fail, a ValueError detailing what went wrong is raised. I then call this function on orders to validate its contents.
